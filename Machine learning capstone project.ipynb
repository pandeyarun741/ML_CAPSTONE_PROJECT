# %%
Project name_Predict Gender using Dental_metrix_ML

# %%
STEP-1 IMPORT ALL LIABRARY

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
STEP-2 LOADING DATASET

# %%
df=pd.read_csv("Dentistry Dataset.csv")

# %%
df.shape
# Out:
# (1100, 14)

# %%
STEP-3 Data preprocessing

# %%
df.head()
# Out:
#    Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0      1        NaN   24  Female                            25.06
# 1      2        NaN   22  Female                            25.78
# 2      3        NaN   23  Female                            23.83
# 3      4        NaN   20  Female                            26.12
# 4      5        NaN   20  Female                            26.36
#
#    intercanine distance casts  right canine width intraoral  \
# 0                       25.05                          6.08
# 1                       25.79                          6.13
# 2                       23.83                          5.91
# 3                       26.12                          6.08
# 4                       26.41                          6.09
#
#    right canine width casts  left canine width intraoral  \
# 0                      6.08                         6.09
# 1                      6.13                         6.33
# 2                      5.96                         6.28
# 3                      6.08                         6.56
# 4                      6.09                         6.50
#
#    left canine width casts  right canine index intra oral  \
# 0                     6.10                          0.242
# 1                     6.33                          0.237
# 2                     6.28                          0.248
# 3                     6.56                          0.232
# 4                     6.50                          0.231
#
#    right canine index casts  left canine index intraoral  \
# 0                     0.242                        0.242
# 1                     0.237                        0.247
# 2                     0.248                        0.264
# 3                     0.232                        0.250
# 4                     0.231                        0.246
#
#    left canine index casts
# 0                    0.241
# 1                    0.247
# 2                    0.264
# 3                    0.250
# 4                    0.246

# %%
df.describe()
# Out:
#              Sl No  Sample ID          Age  inter canine distance intraoral  \
# count  1100.000000        0.0  1100.000000                      1100.000000
# mean    550.500000        NaN    21.625455                        25.989009
# std     317.686953        NaN     2.085892                         1.315292
# min       1.000000        NaN    18.000000                        23.120000
# 25%     275.750000        NaN    20.000000                        25.000000
# 50%     550.500000        NaN    22.000000                        25.900000
# 75%     825.250000        NaN    23.000000                        26.992500
# max    1100.000000        NaN    25.000000                        30.310000
#
#        intercanine distance casts  right canine width intraoral  \
# count                 1100.000000                   1100.000000
# mean                    25.880082                      6.563000
# std                      1.862323                      0.379035
# min                      6.540000                      5.460000
# 25%                     24.980000                      6.290000
# 50%                     25.900000                      6.520000
# 75%                     27.000000                      6.802500
# max                     30.310000                      7.610000
#
#        right canine width casts  left canine width intraoral  \
# count               1100.000000                  1100.000000
# mean                   6.564491                     6.669627
# std                    0.377553                     0.375841
# min                    5.460000                     5.460000
# 25%                    6.300000                     6.400000
# 50%                    6.520000                     6.660000
# 75%                    6.802500                     6.910000
# max                    7.600000                     7.810000
#
#        left canine width casts  right canine index intra oral  \
# count              1100.000000                    1100.000000
# mean                  6.675018                       0.253122
# std                   0.377098                       0.015344
# min                   5.460000                       0.223000
# 25%                   6.407500                       0.242000
# 50%                   6.680000                       0.253000
# 75%                   6.920000                       0.262000
# max                   7.810000                       0.363000
#
#        right canine index casts  left canine index intraoral  \
# count               1100.000000                  1100.000000
# mean                   0.252355                     0.256453
# std                    0.012892                     0.012355
# min                    0.223000                     0.223000
# 25%                    0.242000                     0.247000
# 50%                    0.253000                     0.255000
# 75%                    0.261250                     0.264250
# max                    0.302000                     0.305000
#
#        left canine index casts
# count              1100.000000
# mean                  0.256361
# std                   0.012374
# min                   0.223000
# 25%                   0.247000
# 50%                   0.255000
# 75%                   0.264000
# max                   0.304000

# %%
df.dtypes
# Out:
# Sl No                                int64
# Sample ID                          float64
# Age                                  int64
# Gender                              object
# inter canine distance intraoral    float64
# intercanine distance casts         float64
# right canine width intraoral       float64
# right canine width casts           float64
# left canine width intraoral        float64
# left canine width casts            float64
# right canine index intra oral      float64
# right canine index casts           float64
# left canine index intraoral        float64
# left canine index casts            float64
# dtype: object

# %%
STEP-4 CHECKING MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Sl No                                 0
# Sample ID                          1100
# Age                                   0
# Gender                                0
# inter canine distance intraoral       0
# intercanine distance casts            0
# right canine width intraoral          0
# right canine width casts              0
# left canine width intraoral           0
# left canine width casts               0
# right canine index intra oral         0
# right canine index casts              0
# left canine index intraoral           0
# left canine index casts               0
# dtype: int64

# %%
STEP-5 DATA DROPING UNWANTED COLUMN(AFTER)

# %%
df.sample(10)
# Out:
#      Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 863    864        NaN   19    Male                            26.92
# 685    686        NaN   23    Male                            26.36
# 119    120        NaN   22  Female                            25.87
# 350    351        NaN   19  Female                            25.88
# 362    363        NaN   24  Female                            23.57
# 244    245        NaN   18  Female                            23.88
# 884    885        NaN   20    Male                            26.07
# 970    971        NaN   21    Male                            26.76
# 763    764        NaN   24    Male                            28.82
# 860    861        NaN   21    Male                            25.74
#
#      intercanine distance casts  right canine width intraoral  \
# 863                       26.91                          6.40
# 685                       26.39                          7.10
# 119                       25.88                          6.12
# 350                       25.88                          6.00
# 362                       23.57                          5.94
# 244                       23.88                          6.68
# 884                       26.07                          6.77
# 970                       26.76                          7.00
# 763                       28.82                          7.24
# 860                       25.74                          6.74
#
#      right canine width casts  left canine width intraoral  \
# 863                      6.41                         6.77
# 685                      7.10                         7.28
# 119                      6.12                         6.36
# 350                      6.00                         6.20
# 362                      5.94                         5.94
# 244                      6.68                         6.68
# 884                      6.77                         6.84
# 970                      7.00                         7.00
# 763                      7.24                         7.25
# 860                      6.74                         6.97
#
#      left canine width casts  right canine index intra oral  \
# 863                     6.78                          0.238
# 685                     7.30                          0.269
# 119                     6.36                          0.236
# 350                     6.20                          0.232
# 362                     5.94                          0.252
# 244                     6.68                          0.279
# 884                     6.85                          0.259
# 970                     6.99                          0.260
# 763                     7.24                          0.252
# 860                     6.97                          0.262
#
#      right canine index casts  left canine index intraoral  \
# 863                     0.238                        0.251
# 685                     0.268                        0.276
# 119                     0.236                        0.247
# 350                     0.232                        0.239
# 362                     0.252                        0.252
# 244                     0.279                        0.279
# 884                     0.259                        0.262
# 970                     0.260                        0.260
# 763                     0.252                        0.251
# 860                     0.262                        0.270
#
#      left canine index casts
# 863                    0.251
# 685                    0.276
# 119                    0.247
# 350                    0.239
# 362                    0.252
# 244                    0.279
# 884                    0.262
# 970                    0.260
# 763                    0.252
# 860                    0.270

# %%
HANDLING OUTLIER

# %%
sns.boxplot(x="Age",data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
NO OUTLIERS IN AGE COLUMN

# %%
REMOVING OUTLIERS FROM CLOUMN INTER CANINE

# %%
# Detecting outlier using IQR
Q1=25.0000
Q3=26.99250
IQR=Q3-Q1

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (22.01125, 29.98125)

# %%
df =df[(df['inter canine distance intraoral'] > lower_limit) & (df['inter canine distance intraoral'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1098 rows x 14 columns]

# %%
sns.boxplot(x="inter canine distance intraoral",data=df)
# Out:
# <Axes: xlabel='inter canine distance intraoral'>

# %%
REMOVING OUTLIERS CLOUMN FROM INTERCANINE DISTANCE

# %%
Q1=24.9800
Q3=27.00000
IQR = Q3 - Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (21.950000000000003, 30.03)

# %%
df =df[(df['intercanine distance casts'] > lower_limit) & (df['intercanine distance casts'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1087 rows x 14 columns]

# %%
After Removing outliers from intercanine distance casts

# %%
sns.boxplot(x='intercanine distance casts',data=df)
# Out:
# <Axes: xlabel='intercanine distance casts'>

# %%
#Remove Outliers from column 'right canine width intraoral'

# %%
Q1=6.2900
Q3=6.80
IQR = Q3 - Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (5.525, 7.5649999999999995)

# %%
df =df[(df['right canine width intraoral'] > lower_limit) & (df['right canine width intraoral'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1093 rows x 14 columns]

# %%
#After removing outliers right canine width interaoral>

# %%
sns.boxplot(x='right canine width intraoral',data=df)
# Out:
# <Axes: xlabel='right canine width intraoral'>

# %%
#Remove Outliers from right canine width casts

# %%
Q1=6.30
Q3=6.80
IQR = Q3 - Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (5.55, 7.55)

# %%
df =df[(df['right canine width casts'] > lower_limit) & (df['right canine width casts'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1092 rows x 14 columns]

# %%
sns.boxplot(x='right canine width casts',data=df)
# Out:
# <Axes: xlabel='right canine width casts'>

# %%
Q1=6.40
Q3=6.91
IQR = Q3 - Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (5.635000000000001, 7.675)

# %%
df =df[(df['left canine width intraoral'] > lower_limit) & (df['left canine width intraoral'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1088 rows x 14 columns]

# %%
# After removing outliers from left canine width intraoral

# %%
sns.boxplot(x='left canine width intraoral',data=df)
# Out:
# <Axes: xlabel='left canine width intraoral'>

# %%
#After removing Outliers from left canine width casts

# %%
sns.boxplot(x='left canine width casts',data=df)
# Out:
# <Axes: xlabel='left canine width casts'>

# %%
Q1=0.2420
Q3=0.2602
IQR = Q3-Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (0.2147, 0.2875)

# %%
df =df[(df['right canine index intra oral'] > lower_limit) & (df['right canine index intra oral'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1068 rows x 14 columns]

# %%
#After removing Outliers from column right canine index intra oral

# %%
sns.boxplot(x='right canine index intra oral',data=df)
# Out:
# <Axes: xlabel='right canine index intra oral'>

# %%
Q1=0.2420
Q3=0.26125
IQR = Q3-Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (0.213125, 0.29012499999999997)

# %%
df =df[(df['right canine index casts'] > lower_limit) & (df['right canine index casts'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1068 rows x 14 columns]

# %%
# After removing outliers from right canine index casts

# %%
sns.boxplot(x='right canine index casts',data=df)
# Out:
# <Axes: xlabel='right canine index casts'>

# %%
#Remove outliers from column left canine index intraoral

# %%
Q1=0.2470
Q3=0.26425
IQR = Q3-Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (0.22112500000000002, 0.29012499999999997)

# %%
df =df[(df['left canine index intraoral'] > lower_limit) & (df['left canine index intraoral'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1064 rows x 14 columns]

# %%
# After removing Outliers from left canine index intraoral

# %%
sns.boxplot(x='left canine index intraoral',data=df)
# Out:
# <Axes: xlabel='left canine index intraoral'>

# %%
#Remove Outliers from column left canine index casts

# %%
Q1=0.2470
Q3=0.2640
IQR = Q3-Q1

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (0.22149999999999997, 0.28950000000000004)

# %%
df =df[(df['left canine index casts'] > lower_limit) & (df['left canine index casts'] < upper_limit)]
df
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 0         1        NaN   24  Female                            25.06
# 1         2        NaN   22  Female                            25.78
# 2         3        NaN   23  Female                            23.83
# 3         4        NaN   20  Female                            26.12
# 4         5        NaN   20  Female                            26.36
# ...     ...        ...  ...     ...                              ...
# 1095   1096        NaN   24    Male                            24.29
# 1096   1097        NaN   22    Male                            25.22
# 1097   1098        NaN   25    Male                            24.24
# 1098   1099        NaN   21    Male                            24.87
# 1099   1100        NaN   23    Male                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1064 rows x 14 columns]

# %%
sns.boxplot(x='left canine index casts',data=df)
# Out:
# <Axes: xlabel='left canine index casts'>

# %%
df.shape
# Out:
# (1064, 14)

# %%
Encoding catagorical data Gender

# %%
# import required Library
from sklearn.preprocessing import LabelEncoder

# %%
# Lets fit and transform the Gender column
label_encoder = LabelEncoder()
df['Gender'] = label_encoder.fit_transform(df['Gender'])

# %%
df["Gender"].unique()
# Out:
# array([0, 1])

# %%
catagorical data after encoding

# %%
df.sample(10)
# Out:
#       Sl No  Sample ID  Age  Gender  inter canine distance intraoral  \
# 228     229        NaN   21       0                            24.01
# 1039   1040        NaN   21       1                            28.55
# 306     307        NaN   24       0                            26.25
# 558     559        NaN   24       0                            24.33
# 263     264        NaN   24       0                            27.83
# 856     857        NaN   20       1                            24.81
# 992     993        NaN   21       1                            27.74
# 595     596        NaN   23       0                            25.97
# 74       75        NaN   21       1                            27.81
# 709     710        NaN   25       1                            25.54
#
#       intercanine distance casts  right canine width intraoral  \
# 228                        24.01                          6.18
# 1039                       28.55                          6.86
# 306                        26.25                          6.39
# 558                        24.33                          5.94
# 263                        27.83                          7.05
# 856                        24.81                          6.53
# 992                        27.74                          7.08
# 595                        25.97                          6.46
# 74                         27.81                          6.40
# 709                        25.54                          7.29
#
#       right canine width casts  left canine width intraoral  \
# 228                       6.19                         6.19
# 1039                      6.86                         7.09
# 306                       6.40                         6.39
# 558                       5.94                         5.94
# 263                       7.05                         7.06
# 856                       6.53                         6.86
# 992                       7.08                         7.08
# 595                       6.46                         6.46
# 74                        6.40                         6.40
# 709                       7.29                         7.30
#
#       left canine width casts  right canine index intra oral  \
# 228                      6.18                          0.255
# 1039                     7.09                          0.239
# 306                      6.40                          0.243
# 558                      5.94                          0.244
# 263                      7.07                          0.253
# 856                      6.86                          0.263
# 992                      7.08                          0.255
# 595                      6.46                          0.249
# 74                       6.38                          0.230
# 709                      7.30                          0.285
#
#       right canine index casts  left canine index intraoral  \
# 228                      0.256                        0.256
# 1039                     0.239                        0.248
# 306                      0.243                        0.243
# 558                      0.244                        0.244
# 263                      0.253                        0.253
# 856                      0.263                        0.276
# 992                      0.255                        0.255
# 595                      0.249                        0.249
# 74                       0.230                        0.230
# 709                      0.285                        0.286
#
#       left canine index casts
# 228                     0.256
# 1039                    0.248
# 306                     0.243
# 558                     0.244
# 263                     0.253
# 856                     0.276
# 992                     0.255
# 595                     0.249
# 74                      0.229
# 709                     0.286

# %%
#splite dipendent and independent variables x and y

# %%
# Code to find dependant variable(targeted variable) and independent variable(featured variable)
X = df.drop(['Gender'], axis=1)
y = df['Gender']

# %%
X
# Out:
#       Sl No  Sample ID  Age  inter canine distance intraoral  \
# 0         1        NaN   24                            25.06
# 1         2        NaN   22                            25.78
# 2         3        NaN   23                            23.83
# 3         4        NaN   20                            26.12
# 4         5        NaN   20                            26.36
# ...     ...        ...  ...                              ...
# 1095   1096        NaN   24                            24.29
# 1096   1097        NaN   22                            25.22
# 1097   1098        NaN   25                            24.24
# 1098   1099        NaN   21                            24.87
# 1099   1100        NaN   23                            24.51
#
#       intercanine distance casts  right canine width intraoral  \
# 0                          25.05                          6.08
# 1                          25.79                          6.13
# 2                          23.83                          5.91
# 3                          26.12                          6.08
# 4                          26.41                          6.09
# ...                          ...                           ...
# 1095                       24.29                          6.58
# 1096                       25.22                          6.70
# 1097                       24.24                          6.60
# 1098                       24.87                          6.57
# 1099                       24.51                          6.36
#
#       right canine width casts  left canine width intraoral  \
# 0                         6.08                         6.09
# 1                         6.13                         6.33
# 2                         5.96                         6.28
# 3                         6.08                         6.56
# 4                         6.09                         6.50
# ...                        ...                          ...
# 1095                      6.58                         6.60
# 1096                      6.70                         6.80
# 1097                      6.60                         6.61
# 1098                      6.57                         6.66
# 1099                      6.36                         6.78
#
#       left canine width casts  right canine index intra oral  \
# 0                        6.10                          0.242
# 1                        6.33                          0.237
# 2                        6.28                          0.248
# 3                        6.56                          0.232
# 4                        6.50                          0.231
# ...                       ...                            ...
# 1095                     6.60                          0.271
# 1096                     6.80                          0.265
# 1097                     6.61                          0.272
# 1098                     6.66                          0.264
# 1099                     6.78                          0.259
#
#       right canine index casts  left canine index intraoral  \
# 0                        0.242                        0.242
# 1                        0.237                        0.247
# 2                        0.248                        0.264
# 3                        0.232                        0.250
# 4                        0.231                        0.246
# ...                        ...                          ...
# 1095                     0.271                        0.272
# 1096                     0.265                        0.269
# 1097                     0.272                        0.272
# 1098                     0.264                        0.267
# 1099                     0.259                        0.276
#
#       left canine index casts
# 0                       0.241
# 1                       0.247
# 2                       0.264
# 3                       0.250
# 4                       0.246
# ...                       ...
# 1095                    0.272
# 1096                    0.269
# 1097                    0.272
# 1098                    0.267
# 1099                    0.276
#
# [1064 rows x 13 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1095    1
# 1096    1
# 1097    1
# 1098    1
# 1099    1
# Name: Gender, Length: 1064, dtype: int32

# %%
Normalize the x variables

# %%
#Import required library
from sklearn.preprocessing import Normalizer

# %%
##Exploratory Data Analysis##

# %%
# Correlation matix
corr=df.corr()

# %%
# Generating heatmap
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True,cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
